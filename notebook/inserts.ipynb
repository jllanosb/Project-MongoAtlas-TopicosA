# %% [markdown]
# # Insertando Datos

# %%
from connect import db

libros = db.libros

libro = {
    'Titulo':'La ciudad Verde',
    'Autor': 'Mario Vargas Llosa',
    'Anio': 1965,
    'Categoria': ['Novela', 'Peruana'],
    'Stock': 4
}

# Insertar de un documento (Fila)
res = libros.insert_one(libro)
print('Inserted ID', res.inserted_id)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from connect import db
#       3 libros = db.libros
#       5 libro = {
#       6     'Titulo':'La ciudad Verde',
#       7     'Autor': 'Mario Vargas Llosa',
#    (...)     10     'Stock': 4
#      11 }
#
# File c:\Users\LAB03_PC_DOCENTE\documents\Project-MongoAtlas-TopicosA\notebook\connect.py:1
# ----> 1 from pymongo  import MongoClient, errors
#       2 from dotenv import load_dotenv
#       3 import os
#
# ModuleNotFoundError: No module named 'pymongo'
